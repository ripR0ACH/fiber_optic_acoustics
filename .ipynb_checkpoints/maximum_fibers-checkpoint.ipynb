# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2 * np.pi, 1000)
r = 10
plt.plot(r * np.cos(theta), r * np.sin(theta))
bundle_area = np.pi * r ** 2
fibers = 1000
fiber_area_estimate = bundle_area / fibers
print(fiber_area_estimate)
# Out:
# 0.3141592653589793
